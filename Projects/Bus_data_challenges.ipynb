# %% [markdown]
# <a href="https://colab.research.google.com/github/JackSandford/ECK/blob/main/Projects/Bus_data_challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bus emissions challenge
# ---
#
#
# ### Introduction
#
# Kent and Medway have the highest proportion of old buses in the country (~40% of fleet). Old buses are detrimental to the environment as the older buses only have Euro III emissions standards which if used for lots of
# journeys will be dramatically impacting the air quality of the area.
#
# The client therefore would like us to find out some information which could then be used as evidence to make a case  to improve the bus emissions in the Kent and Medway area.
#
# The datasets we will be using are pubically available. Gov.uk provides data on all bus journeys in the UK and when used in conjunction with Arriva buses fleet emissions data (available from bustimes.org, download [here](https://drive.google.com/uc?export=download&id=1ywtiSwR27JYCC5Sf9G1ZCTOTWNxWBk9_ )) we can build a pretty good
# picture of how many of these old buses are being used for bus journeys in Kent and Medway.
#
# The gov.uk bus data is available in XML format via an api. The data refreshes every 10 seconds so each time you download it, it will show you a snapshot of the buses currently in operation at that time. We have downloaded one snapshot of this
# data and converted it to JSON format accessible to download [here](https://drive.google.com/uc?export=download&id=1a9vMs0Kke7Nh4LuxCnKHkVIkFDr-az_Z)

# %% [markdown]
# ### Load the data
# ---
# #### **Please run the cell below to load the data required for this challenge.**
# The following code will read both the json file and the bus emissions csv file and create a dictionary (`bus_journeys`) and 2 lists (`vehicle_refs`, `emissions`).

# %%
import pandas as pd
import json
import urllib.request

url_json = "https://drive.google.com/uc?export=download&id=1a9vMs0Kke7Nh4LuxCnKHkVIkFDr-az_Z"
csv = "https://drive.google.com/uc?export=download&id=1ywtiSwR27JYCC5Sf9G1ZCTOTWNxWBk9_"

def get_saved_data(url_json):
    if url_json is not None:
        try:
            with urllib.request.urlopen(url_json) as url:
                data = json.loads(url.read().decode())
                return data
        except:
            print("An error occurred while reading the file")


def get_dicts_lists():
  df = pd.json_normalize(get_saved_data(url_json))
  regs = pd.read_csv(csv)

  bus = df[['MonitoredVehicleJourney.LineRef','MonitoredVehicleJourney.DirectionRef','MonitoredVehicleJourney.PublishedLineName','MonitoredVehicleJourney.OriginName','MonitoredVehicleJourney.DestinationName','MonitoredVehicleJourney.OriginAimedDepartureTime','MonitoredVehicleJourney.VehicleRef']]
  bus.columns = bus.columns.str.lstrip("MonitoredVehicleJourney.")
  bus_journeys = bus.to_dict('records')
  
  regs.rename({'Last tracked': 'VehicleRef'}, axis=1 , inplace=True)
  vehiclerefs = regs['VehicleRef'].to_list()
  emission_standards = regs['Emission Class'].to_list()
  return bus_journeys, vehiclerefs, emission_standards

def get_emissions_data():

  emissions_data = [
      {"Standard":"EURO III", "CO2":2.1, "Nox":5, "PM":0.1 },
      {"Standard":"EURO IV","CO2":1.5,"Nox":3.5,"PM":0.02 },
      {"Standard":"EURO V","CO2":1.5,"Nox":2,"PM":0.02},
      {"Standard":"EURO VI","CO2":1.5,"Nox":0.4,"PM":0.01}
  ]
  return emissions_data



bus_journeys, vehicle_refs, emission_standards = get_dicts_lists()
emissions_data = get_emissions_data()

# %% [markdown]
# ### Task 1 - investigate bus_journeys data
# ---

# %% [markdown]
# This is the data dictionary for records in the bus_journeys data (all fields are alphanumeric):
#
# LineRef--------------------------------------bus route number
# DirectionRef------------------------------current direction of travel, inbound or outbound
# PublishedLineName------------------timetabled service name (may be same as LineRef)
# OriginName-------------------------------start location of the current route
# DestinationName----------------------end destination on the current route
# OriginAimedDepartureTime------the time at which the bus was timetabled to leave its start location
# Ref---------------------------------------------a uniquely identifier for the bus vehicle
#
# The bus_journeys data contains a list of records with the fields shown above.  This list contains a records for each bus that is currently on a bus route (assuming that all are tranmitting their locations)
#
# **Task**
# Take a look at the `bus_journeys` dictionary
#
# * Print the first record
# * Print the last record
# * How is an individual bus journey dictionary structured?
# * How many of these dictionary records are in the list?
#
#
# **Expected Output**
# First record will have `LineRef` 177
# Last record will have `LineRef` 347

# %%
import pandas as pd
import json
import urllib.request

url_json = "https://drive.google.com/uc?export=download&id=1a9vMs0Kke7Nh4LuxCnKHkVIkFDr-az_Z"
csv = "https://drive.google.com/uc?export=download&id=1ywtiSwR27JYCC5Sf9G1ZCTOTWNxWBk9_"

def get_saved_data(url_json):
    if url_json is not None:
        try:
            with urllib.request.urlopen(url_json) as url:
                data = json.loads(url.read().decode())
                return data
        except:
            print("An error occurred while reading the file")


def get_dicts_lists():
  df = pd.json_normalize(get_saved_data(url_json))
  regs = pd.read_csv(csv)

  bus = df[['MonitoredVehicleJourney.LineRef','MonitoredVehicleJourney.DirectionRef','MonitoredVehicleJourney.PublishedLineName','MonitoredVehicleJourney.OriginName','MonitoredVehicleJourney.DestinationName','MonitoredVehicleJourney.OriginAimedDepartureTime','MonitoredVehicleJourney.VehicleRef']]
  bus.columns = bus.columns.str.lstrip("MonitoredVehicleJourney.")
  bus_journeys = bus.to_dict('records')
  
  regs.rename({'Last tracked': 'VehicleRef'}, axis=1 , inplace=True)
  vehiclerefs = regs['VehicleRef'].to_list()
  emission_standards = regs['Emission Class'].to_list()
  return bus_journeys, vehiclerefs, emission_standards

def get_emissions_data():

  emissions_data = [
      {"Standard":"EURO III", "CO2":2.1, "Nox":5, "PM":0.1 },
      {"Standard":"EURO IV","CO2":1.5,"Nox":3.5,"PM":0.02 },
      {"Standard":"EURO V","CO2":1.5,"Nox":2,"PM":0.02},
      {"Standard":"EURO VI","CO2":1.5,"Nox":0.4,"PM":0.01}
  ]
  return emissions_data



bus_journeys, vehicle_refs, emission_standards = get_dicts_lists()
emissions_data = get_emissions_data()

print(bus_journeys[0])
print(bus_journeys[-1])
print('It is structured as a JSON with dictionaries inside of lists.') 
print('There are about 1096 dictionaries in the list')
# Out:
# {'LineRef': '177', 'DirectionRef': 'inbound', 'PublishedLineName': '177', 'OriginName': 'Village_Centre', 'DestinationName': 'Victoria_Street', 'OriginAimedDepartureTime': '2022-09-07T11:20:00+00:00', 'Ref': '1655'}
# {'LineRef': '347', 'DirectionRef': 'anticlockwise', 'PublishedLineName': '347', 'OriginName': 'Bus_Hub', 'DestinationName': 'Coldharbour_Lane_East', 'OriginAimedDepartureTime': '2022-09-07T12:05:00+00:00', 'Ref': '1633'}
# It is structured as a JSON with dictionaries inside of lists.
# There are about 1096 dictionaries in the list

# %% [markdown]
# ### Task 2 - investigate vehicle_refs and emission_standards data lists
# ---
# Take a look at the `vehicle_refs` and `emission_standards` lists
# * what is the length of each list?
# * find how many unique items there are in the emission_standards list - (**hint** : you will need to create another list and use a for loop) *italicised text*
# * print the unique emission_standards items
# * find how many unique items there are in the vehicle_refs list
# * print the length of the unique vehicle_ref items

# %%
print(len(vehicle_refs), 'characters')
print(len(emission_standards), 'characters')
uniqueles = []
uniquelvr = []
sum = 0
for item in emission_standards:
  if item not in uniqueles:
    uniqueles.append(item)
print(uniqueles)
for item in vehicle_refs:
  if item not in uniquelvr:
    uniquelvr.append(item)
for item in uniquelvr:
  sum = sum + 1
print(sum)
print(len(uniquelvr), 'characters')
# Out:
# 223 characters
# 223 characters
# ['EURO III', 'EURO IV', 'EURO V', 'EURO VI']
# 223
# 223 characters

# %% [markdown]
# ### Task 3
# ---
# The client is only concerned about bus routes 116 and 132 specifically.
#
# **Task**
# Create a new list of dictionaries which contains only the records where the `LineRef` is either 116 or 132.
#
# *(**hint**: the datatype of the LineRef might not be what you expect - the data came from a .csv file)*
#
# **Expected output**
# There will be 14 records in this list

# %%
two_routes = []
for route in bus_journeys:
  if route['LineRef'] == '116' or route['LineRef'] == '132':
    two_routes.append(route)
print(len(two_routes))
# Out:
# 14

# %% [markdown]
# ### Task 4
# ---
#
# The indexes of `vehicle_refs` match the indexes of `emissions`.
# Create a new list, which contains dictionaries.  Each dictionary will contain a vehicle_ref and its corresponding emission_class.
# *hint: you will need to use a for loop and indexing and should create dictionaries with two keys: vehicle_ref and emission_class*

# %%
refvcls = []
for k,v in zip(vehicle_refs,emission_standards):
    refvcls.append({'vehicle_ref': k,'emission_standard': v})
for line in refvcls:
  print(line)
# Out:
# {'vehicle_ref': '6260', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '1607', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '1609', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '1616', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6401', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6402', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6404', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6405', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6406', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6407', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6408', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6410', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6411', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6412', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6413', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6417', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6418', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6419', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6420', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6421', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6422', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6423', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6424', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6425', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6427', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6428', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6429', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6430', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6431', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6432', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6436', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6437', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6438', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6439', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6440', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6441', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6442', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6443', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6444', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6445', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6446', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6447', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6448', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6449', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6005', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6007', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6136', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6132', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6135', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6129', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6124', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6125', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6126', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6127', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6152', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6154', 'emission_standard': 'EURO III'}
# {'vehicle_ref': '6139', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6138', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6143', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6141', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6144', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1633', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1634', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1635', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1636', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3984', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3987', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3988', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3994', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3995', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3996', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1637', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1638', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1639', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1640', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1641', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1642', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '4007', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '4006', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '4005', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6146', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6147', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6150', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6151', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6149', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6148', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6237', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '6238', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '1523', 'emission_standard': 'EURO IV'}
# {'vehicle_ref': '3906', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '3908', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6200', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6201', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6203', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6205', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4046', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4048', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4050', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4051', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4054', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4055', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4056', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4057', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4058', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4059', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4013', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4014', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4060', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4061', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4062', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4063', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4064', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4065', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4066', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4224', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4219', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4220', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4221', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4222', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4223', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1653', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1650', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1652', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1651', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4218', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1654', 'emission_standard': 'EURO V'}
# {'vehicle_ref': 'T83', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4464', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4469', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4470', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4471', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4455', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4460', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4463', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4450', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4452', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6471', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '6472', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1522', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1518', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1519', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1503', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1524', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '1526', 'emission_standard': 'EURO V'}
# {'vehicle_ref': '4279', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4280', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4281', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4282', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4283', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4284', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1655', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4263', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4289', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4290', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4291', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4292', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4293', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4294', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4295', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4296', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4297', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4298', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4299', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4300', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4308', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4309', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4310', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4311', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4312', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4313', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4314', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4315', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4316', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4317', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4318', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4319', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4264', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4265', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4266', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4267', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4268', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4269', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4270', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4271', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4272', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4273', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4261', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1656', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1657', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1658', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1659', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1660', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '1661', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4233', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4234', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4071', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4072', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4073', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4074', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4075', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6479', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6480', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6481', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6482', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6483', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6484', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4106', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4108', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6516', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4120', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4121', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '4126', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6520', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6521', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6522', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6528', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6473', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6474', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6475', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6476', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6477', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6478', 'emission_standard': 'EURO VI'}
# {'vehicle_ref': '6493', 'emission_standard': 'EURO VI'}

# %% [markdown]
# ### Task 5
# ---
#
# The list of dictionaries you created in the last exercise is very long. A more intuitive way to hold this data would be by collating data.
#
# Create a dictionary where each unique emission_class is a key and its corresponding value is a list of all vehicle_refs with that emission_class
#
# *(**hint**: you could think about using the unique_em list you created earlier)*
#
# **Example Output**
#
# {"EURO III": [1234, 4567, 8910], "EURO IV": [1028, 1283, 1234]}

# %%
eur3 = []
eur4 = []
eur5 = []
eur6 = []
for record in refvcls:
  for k,v in record.items():
    if v == 'EURO III':
      eur3.append(record.get('vehicle_ref'))
    elif v == 'EURO IV':
      eur4.append(record.get('vehicle_ref'))
    elif v == 'EURO V':
      eur5.append(record.get('vehicle_ref'))
    elif v == 'EURO VI':
      eur6.append(record.get('vehicle_ref'))
clsvref = {
    'EURO III' : eur3,
    'EURO IV' : eur4,
    'EURO V ' : eur5,
    'EURO VI' : eur6
}
for line in clsvref.items():
  print(line)
# Out:
# ('EURO III', ['6260', '1607', '1609', '1616', '6401', '6402', '6404', '6405', '6406', '6407', '6408', '6410', '6411', '6412', '6413', '6417', '6418', '6419', '6420', '6421', '6422', '6423', '6424', '6425', '6427', '6428', '6429', '6430', '6431', '6432', '6436', '6437', '6438', '6439', '6440', '6441', '6442', '6443', '6444', '6445', '6446', '6447', '6448', '6449', '6005', '6007', '6136', '6132', '6135', '6129', '6124', '6125', '6126', '6127', '6152', '6154'])
# ('EURO IV', ['6139', '6138', '6143', '6141', '6144', '1633', '1634', '1635', '1636', '3984', '3987', '3988', '3994', '3995', '3996', '1637', '1638', '1639', '1640', '1641', '1642', '4007', '4006', '4005', '6146', '6147', '6150', '6151', '6149', '6148', '6237', '6238', '1523'])
# ('EURO V ', ['3906', '3908', '6200', '6201', '6203', '6205', '4046', '4048', '4050', '4051', '4054', '4055', '4056', '4057', '4058', '4059', '4013', '4014', '4060', '4061', '4062', '4063', '4064', '4065', '4066', '4224', '4219', '4220', '4221', '4222', '4223', '1653', '1650', '1652', '1651', '4218', '1654', 'T83', '4464', '4469', '4470', '4471', '4455', '4460', '4463', '4450', '4452', '6471', '6472', '1522', '1518', '1519', '1503', '1524', '1526'])
# ('EURO VI', ['4279', '4280', '4281', '4282', '4283', '4284', '1655', '4263', '4289', '4290', '4291', '4292', '4293', '4294', '4295', '4296', '4297', '4298', '4299', '4300', '4308', '4309', '4310', '4311', '4312', '4313', '4314', '4315', '4316', '4317', '4318', '4319', '4264', '4265', '4266', '4267', '4268', '4269', '4270', '4271', '4272', '4273', '4261', '1656', '1657', '1658', '1659', '1660', '1661', '4233', '4234', '4071', '4072', '4073', '4074', '4075', '6479', '6480', '6481', '6482', '6483', '6484', '4106', '4108', '6516', '4120', '4121', '4126', '6520', '6521', '6522', '6528', '6473', '6474', '6475', '6476', '6477', '6478', '6493'])

# %% [markdown]
# ### Task 6
# ---
# Find all the polluting buses that were running when the data was collected.
# Using the `bus_journeys` dictionary, find all the records where a Euro III bus was used.
#
# You can find the `Refs` which are polluting from the dictionary you created in the last task.
#
# * Create a new list of dictionaries which only contains the records from `bus_journeys` which were found as polluting bus.
# * how many polluting buses were being used?

# %%
#match up euro 3 dictionary with bus journeys data
current_eur3 = []
for bus in bus_journeys:
  for k,v in bus.items():
    if bus.get('Ref') in eur3 and bus.get('Ref') not in current_eur3:
      current_eur3.append(bus.items())
print(current_eur3)
len(current_eur3)
# Out:
# [dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '116'), ('DirectionRef', 'outbound'), ('PublishedLineName', '116'), ('OriginName', 'Waterfront_Bus_Station'), ('DestinationName', 'Hempstead_Valley_Shopping_Centre'), ('OriginAimedDepartureTime', '2022-09-07T11:12:00+00:00'), ('Ref', '6430')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '2'), ('DirectionRef', 'inbound'), ('PublishedLineName', '2'), ('OriginName', 'Chatham_Railway_Station'), ('DestinationName', 'Dockside_Outlet'), ('OriginAimedDepartureTime', '2022-09-07T12:08:00+00:00'), ('Ref', '6428')]), dict_items([('LineRef', '100'), ('DirectionRef', 'inbound'), ('PublishedLineName', '100'), ('OriginName', 'Goldcrest_Drive'), ('DestinationName', 'Chatham_Railway_Station'), ('OriginAimedDepartureTime', '2022-09-07T10:21:00+00:00'), ('Ref', '6410')]), dict_items([('LineRef', '100'), ('DirectionRef', 'inbound'), ('PublishedLineName', '100'), ('OriginName', 'Goldcrest_Drive'), (' ...
# 210

# %% [markdown]
# # Challenge
#
# Can we find out how much pollution one bus on the 116 route emits?
#
# Can we find out how much pollution one bus on the 132 route emits?
#
# Can we find out how much pollution, in total, all the buses on these routes at the recorded point in time will be emitting?
#
# **Some numbers to play with:**
# NOTE: These are NOT fact checked but give a rough idea of some numbers we might be able to use for a rough first model
#
# *  A typical old diesel bus will typically get 5 miles per gallon, which is 2.126km per litre (divide mpg by 2.352)
# *  One litre of diesel fuel has the energy content of 10.8 kWh
# *  If the bus's fuel consumption is 2.126km per litre, this gives an energy content of 5.08 kWh/km (divide 10.8 by fuel consumption)
#
# Emissions data is in this variable: ***emissions_data***
#
# **Emissions Data dictionary**
#
# Field------------------------------Data Type------------Description
# Emission Standard-------Alphanumeric------Euro III, IV, V or VI
# CO2-------------------------------Float--------------------grams of CO2 emitted per KWhr
# Nox-------------------------------Float--------------------grams of Nox emitted per KWhr
# PM--------------------------------Float--------------------grams of particulate matter emitted per gm/KWhr
#
# **Route information**
# The 132 route is 12.5km from end to end
# The 116 route is 15.25km
#
# ####**Task**
#
# Write a function that takes the miles per gallon and the route (LineRef) as a parameter and calculates the emission of each of the 3 pollutants for a return journey on that route.
#
# ####**Extension**
#
# Find all the 116 and 132 buses in the data set (a snapshot of what is on the road at that particular point in time).
#
# Count how many of these buses are Euro III.
#
# Then calculate the total emissions for each pollutant for all the buses you have found.

# %%
def emissions(mpg, route):
  kmpl = mpg / 2.352
  eng = 10.8
  engkm = eng / kmpl
  l132 = 12.5
  l116 = 15.25
  if route == '132': length = 12.5
  elif route == '116': length = 15.25
  total_energy = float(length) * engkm
  co2 = emissions_data[0]['CO2']
  nox = emissions_data[0]['Nox']
  pm = emissions_data[0]['PM']
  totalco2 = co2 * total_energy
  totalnox = nox * total_energy
  totalpm = pm * total_energy
  return totalco2, totalnox, totalpm

emissions132 = emissions(5,'132')
print(emissions132)
print(two_routes)
treur3 = []
for k,v in zip(two_routes,emission_standards):
    for line in two_routes:
      ref = line['Ref']
      print(ref)
#    treur3.append({'vehicle_ref': k,'emission_standard': v})
for line in zip(refvcls,two_routes):
  if ref == line['vehicle_ref']:
    treur3.append(ref)
#how many 116 and 132 are eu3
#multiply emissions 
#by number of buses on each route
# Out:
# (133.3584, 317.52, 6.3504)
# [{'LineRef': '116', 'DirectionRef': 'inbound', 'PublishedLineName': '116', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T11:51:00+00:00', 'Ref': '4290'}, {'LineRef': '132', 'DirectionRef': 'inbound', 'PublishedLineName': '132', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T11:30:00+00:00', 'Ref': '4309'}, {'LineRef': '116', 'DirectionRef': 'outbound', 'PublishedLineName': '116', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T11:12:00+00:00', 'Ref': '6430'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T08:53:00+00:00', 'Ref': '6480'}, {'LineRef': '116', 'DirectionRef': 'outbound', 'PublishedLineName': '116', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T11:42:00+00:00', 'Ref': '1641'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T12:06:00+00:00', 'Ref': '6481'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T09:30:00+00:00', 'Ref': '4261'}, {'LineRef': '132', 'DirectionRef': 'inbound', 'PublishedLineName': '132', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T12:06:00+00:00', 'Ref': '6411'}, {'LineRef': '116', 'DirectionRef': 'inbound', 'PublishedLineName': '116', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T11:21:00+00:00', 'Ref': '4300'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T11:54:00+00:00', 'Ref': '4318'}, {'LineRef': '132', 'DirectionRef': 'inbound', 'PublishedLineName': '132', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T11:42:00+00:00', 'Ref': '4269'}, {'LineRef': '116', 'DirectionRef': 'outbound', 'PublishedLineName': '116', 'OriginName': 'Waterfront_Bus_Station', 'DestinationName': 'Hempstead_Valley_Shopping_Centre', 'OriginAimedDepartureTime': '2022-09-07T12:12:00+00:00', 'Ref': '4308'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T11:30:00+00:00', 'Ref': '4054'}, {'LineRef': '132', 'DirectionRef': 'outbound', 'PublishedLineName': '132', 'OriginName': 'Hempstead_Valley_Shopping_Centre', 'DestinationName': 'Waterfront_Bus_Station', 'OriginAimedDepartureTime': '2022-09-07T11:42:00+00:00', 'Ref': '4222'}]
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# 4290
# 4309
# 6430
# 6480
# 1641
# 6481
# 4261
# 6411
# 4300
# 4318
# 4269
# 4308
# 4054
# 4222
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-964f7cda4c96> in <module>
#      26 #    treur3.append({'vehicle_ref': k,'emission_standard': v})
#      27 for line in zip(refvcls,two_routes):
# ---> 28   if ref == line['vehicle_ref']:
#      29     treur3.append(ref)
#      30 #how many 116 and 132 are eu3
#
# TypeError: tuple indices must be integers or slices, not str

# %% [markdown]
# # Summary
#
# Having completed the challenges.  What new information do we know?  What more might we try to find?
#
# Add some ideas in the box below (double click to open it)
